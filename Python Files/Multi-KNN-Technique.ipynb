# %% [markdown]
# ## ENGG* 6600 Security of Cyber Grids
# ### Prof. Hadis Karimipour
#
# ### Project Title - Identifying suspicious URLs using Supervised Learning and Lexical Analysis
#
# #### Coded by Ruthvik Raja M.V (1162634) and Debanjan Mitra (1126062)

# %% [markdown]
# ### Multi Classification using KNN and PCA ###

# %%
# Importing all the necessary libraries
import pandas as pd
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.decomposition import PCA

# %%
# Loading Malware, Spam, Phishing and Defacement Datasets
# Each Dataset also consists of Benign URL's

malware=pd.read_csv("Dataset/Malware.csv")
spam=pd.read_csv("Dataset/Spam.csv")
phishing=pd.read_csv("Dataset/Phishing.csv")
defacement=pd.read_csv("Dataset/Defacement.csv")

# %%
# Data Cleaning: Strip whitespaces from the column names and drop NA values

malware = malware.rename(str.strip, axis='columns')
spam=spam.rename(str.strip, axis="columns")
phishing=phishing.rename(str.strip, axis="columns")
defacement=defacement.rename(str.strip, axis="columns")

# %%
# In Malware Dataset nearly 40% of values are NULL values in the NumberRate_Extension column
 # and also from the Binary classification analysis it is clear that the Entropy_DirectoryName has no 
  # impact on the output column so, dropping the column NumberRate_Extension from Spam, Malware and 
   # Phishing Datasets

malware1=malware.drop(["NumberRate_Extension", "Entropy_DirectoryName"], axis=1)
malware1=malware1.dropna()
malware1=shuffle(malware1)
malware1=malware1.reset_index(drop=True)
malware1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14312 entries, 0 to 14311
# Data columns (total 78 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Querylength                      14312 non-null  int64
#  1   domain_token_count               14312 non-null  int64
#  2   path_token_count                 14312 non-null  int64
#  3   avgdomaintokenlen                14312 non-null  float64
#  4   longdomaintokenlen               14312 non-null  int64
#  5   avgpathtokenlen                  14312 non-null  float64
#  6   tld                              14312 non-null  int64
#  7   charcompvowels                   14312 non-null  int64
#  8   charcompace                      14312 non-null  int64
#  9   ldl_url                          14312 non-null  int64
#  10  ldl_domain                       14312 non-null  int64
#  11  ldl_path                         14312 non-null  int64
#  12  ldl_filename                     14312 non-null  int64
#  13  ldl_getArg                       14312 non-null  int64
#  14  dld_url                          14312 non-null  int64
#  15  dld_domain                       14312 non-null  int64
#  16  dld_path                         14312 non-null  int64
#  17  dld_filename                     14312 non-null  int64
#  18  dld_getArg                       14312 non-null  int64
#  19  urlLen                           14312 non-null  int64
#  20  domainlength                     14312 non-null  int64
#  21  pathLength                       14312 non-null  int64
#  22  subDirLen                        14312 non-null  int64
#  23  fileNameLen                      14312 non-null  int64
#  24  this.fileExtLen                  14312 non-null  int64
#  25  ArgLen                           14312 non-null  int64
#  26  pathurlRatio                     14312 non-null  float64
#  27  ArgUrlRatio                      14312 non-null  float64
#  28  argDomanRatio                    14312 non-null  float64
#  29  domainUrlRatio                   14312 non-null  float64
#  30  pathDomainRatio                  14312 non-null  float64
#  31  argPathRatio                     14312 non-null  float64
#  32  executable                       14312 non-null  int64
#  33  isPortEighty                     14312 non-null  int64
#  34  NumberofDotsinURL                14312 non-null  int64
#  35  ISIpAddressInDomainName          14312 non-null  int64
#  36  CharacterContinuityRate          14312 non-null  float64
#  37  LongestVariableValue             14312 non-null  int64
#  38  URL_DigitCount                   14312 non-null  int64
#  39  host_DigitCount                  14312 non-null  int64
#  40  Directory_DigitCount             14312 non-null  int64
#  41  File_name_DigitCount             14312 non-null  int64
#  42  Extension_DigitCount             14312 non-null  int64
#  43  Query_DigitCount                 14312 non-null  int64
#  44  URL_Letter_Count                 14312 non-null  int64
#  45  host_letter_count                14312 non-null  int64
#  46  Directory_LetterCount            14312 non-null  int64
#  47  Filename_LetterCount             14312 non-null  int64
#  48  Extension_LetterCount            14312 non-null  int64
#  49  Query_LetterCount                14312 non-null  int64
#  50  LongestPathTokenLength           14312 non-null  int64
#  51  Domain_LongestWordLength         14312 non-null  int64
#  52  Path_LongestWordLength           14312 non-null  int64
#  53  sub-Directory_LongestWordLength  14312 non-null  int64
#  54  Arguments_LongestWordLength      14312 non-null  int64
#  55  URL_sensitiveWord                14312 non-null  int64
#  56  URLQueries_variable              14312 non-null  int64
#  57  spcharUrl                        14312 non-null  int64
#  58  delimeter_Domain                 14312 non-null  int64
#  59  delimeter_path                   14312 non-null  int64
#  60  delimeter_Count                  14312 non-null  int64
#  61  NumberRate_URL                   14312 non-null  float64
#  62  NumberRate_Domain                14312 non-null  float64
#  63  NumberRate_DirectoryName         14312 non-null  float64
#  64  NumberRate_FileName              14312 non-null  float64
#  65  NumberRate_AfterPath             14312 non-null  float64
#  66  SymbolCount_URL                  14312 non-null  int64
#  67  SymbolCount_Domain               14312 non-null  int64
#  68  SymbolCount_Directoryname        14312 non-null  int64
#  69  SymbolCount_FileName             14312 non-null  int64
#  70  SymbolCount_Extension            14312 non-null  int64
#  71  SymbolCount_Afterpath            14312 non-null  int64
#  72  Entropy_URL                      14312 non-null  float64
#  73  Entropy_Domain                   14312 non-null  float64
#  74  Entropy_Filename                 14312 non-null  float64
#  75  Entropy_Extension                14312 non-null  float64
#  76  Entropy_Afterpath                14312 non-null  float64
#  77  URL_Type_obf_Type                14312 non-null  object
# dtypes: float64(19), int64(58), object(1)
# memory usage: 8.5+ MB

# %%
# In Spam Dataset nearly 34% of values are NULL values in the NumberRate_Extension column

spam1=spam.drop(["NumberRate_Extension", "Entropy_DirectoryName"], axis=1)
spam1=spam1.dropna()
spam1=shuffle(spam1)
spam1=spam1.reset_index(drop=True)
spam1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14294 entries, 0 to 14293
# Data columns (total 78 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Querylength                      14294 non-null  int64
#  1   domain_token_count               14294 non-null  int64
#  2   path_token_count                 14294 non-null  int64
#  3   avgdomaintokenlen                14294 non-null  float64
#  4   longdomaintokenlen               14294 non-null  int64
#  5   avgpathtokenlen                  14294 non-null  float64
#  6   tld                              14294 non-null  int64
#  7   charcompvowels                   14294 non-null  int64
#  8   charcompace                      14294 non-null  int64
#  9   ldl_url                          14294 non-null  int64
#  10  ldl_domain                       14294 non-null  int64
#  11  ldl_path                         14294 non-null  int64
#  12  ldl_filename                     14294 non-null  int64
#  13  ldl_getArg                       14294 non-null  int64
#  14  dld_url                          14294 non-null  int64
#  15  dld_domain                       14294 non-null  int64
#  16  dld_path                         14294 non-null  int64
#  17  dld_filename                     14294 non-null  int64
#  18  dld_getArg                       14294 non-null  int64
#  19  urlLen                           14294 non-null  int64
#  20  domainlength                     14294 non-null  int64
#  21  pathLength                       14294 non-null  int64
#  22  subDirLen                        14294 non-null  int64
#  23  fileNameLen                      14294 non-null  int64
#  24  this.fileExtLen                  14294 non-null  int64
#  25  ArgLen                           14294 non-null  int64
#  26  pathurlRatio                     14294 non-null  float64
#  27  ArgUrlRatio                      14294 non-null  float64
#  28  argDomanRatio                    14294 non-null  float64
#  29  domainUrlRatio                   14294 non-null  float64
#  30  pathDomainRatio                  14294 non-null  float64
#  31  argPathRatio                     14294 non-null  float64
#  32  executable                       14294 non-null  int64
#  33  isPortEighty                     14294 non-null  int64
#  34  NumberofDotsinURL                14294 non-null  int64
#  35  ISIpAddressInDomainName          14294 non-null  int64
#  36  CharacterContinuityRate          14294 non-null  float64
#  37  LongestVariableValue             14294 non-null  int64
#  38  URL_DigitCount                   14294 non-null  int64
#  39  host_DigitCount                  14294 non-null  int64
#  40  Directory_DigitCount             14294 non-null  int64
#  41  File_name_DigitCount             14294 non-null  int64
#  42  Extension_DigitCount             14294 non-null  int64
#  43  Query_DigitCount                 14294 non-null  int64
#  44  URL_Letter_Count                 14294 non-null  int64
#  45  host_letter_count                14294 non-null  int64
#  46  Directory_LetterCount            14294 non-null  int64
#  47  Filename_LetterCount             14294 non-null  int64
#  48  Extension_LetterCount            14294 non-null  int64
#  49  Query_LetterCount                14294 non-null  int64
#  50  LongestPathTokenLength           14294 non-null  int64
#  51  Domain_LongestWordLength         14294 non-null  int64
#  52  Path_LongestWordLength           14294 non-null  int64
#  53  sub-Directory_LongestWordLength  14294 non-null  int64
#  54  Arguments_LongestWordLength      14294 non-null  int64
#  55  URL_sensitiveWord                14294 non-null  int64
#  56  URLQueries_variable              14294 non-null  int64
#  57  spcharUrl                        14294 non-null  int64
#  58  delimeter_Domain                 14294 non-null  int64
#  59  delimeter_path                   14294 non-null  int64
#  60  delimeter_Count                  14294 non-null  int64
#  61  NumberRate_URL                   14294 non-null  float64
#  62  NumberRate_Domain                14294 non-null  float64
#  63  NumberRate_DirectoryName         14294 non-null  float64
#  64  NumberRate_FileName              14294 non-null  float64
#  65  NumberRate_AfterPath             14294 non-null  float64
#  66  SymbolCount_URL                  14294 non-null  int64
#  67  SymbolCount_Domain               14294 non-null  int64
#  68  SymbolCount_Directoryname        14294 non-null  int64
#  69  SymbolCount_FileName             14294 non-null  int64
#  70  SymbolCount_Extension            14294 non-null  int64
#  71  SymbolCount_Afterpath            14294 non-null  int64
#  72  Entropy_URL                      14294 non-null  float64
#  73  Entropy_Domain                   14294 non-null  float64
#  74  Entropy_Filename                 14294 non-null  float64
#  75  Entropy_Extension                14294 non-null  float64
#  76  Entropy_Afterpath                14294 non-null  float64
#  77  URL_Type_obf_Type                14294 non-null  object
# dtypes: float64(19), int64(58), object(1)
# memory usage: 8.5+ MB

# %%
# In Phishing Dataset nearly 48% of values are NULL values in the NumberRate_Extension column

phishing1=phishing.drop(["NumberRate_Extension", "Entropy_DirectoryName"], axis=1)
phishing1=phishing1.dropna()
phishing1=shuffle(phishing1)
phishing1=phishing1.reset_index(drop=True)
phishing1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14889 entries, 0 to 14888
# Data columns (total 78 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Querylength                      14889 non-null  int64
#  1   domain_token_count               14889 non-null  int64
#  2   path_token_count                 14889 non-null  int64
#  3   avgdomaintokenlen                14889 non-null  float64
#  4   longdomaintokenlen               14889 non-null  int64
#  5   avgpathtokenlen                  14889 non-null  float64
#  6   tld                              14889 non-null  int64
#  7   charcompvowels                   14889 non-null  int64
#  8   charcompace                      14889 non-null  int64
#  9   ldl_url                          14889 non-null  int64
#  10  ldl_domain                       14889 non-null  int64
#  11  ldl_path                         14889 non-null  int64
#  12  ldl_filename                     14889 non-null  int64
#  13  ldl_getArg                       14889 non-null  int64
#  14  dld_url                          14889 non-null  int64
#  15  dld_domain                       14889 non-null  int64
#  16  dld_path                         14889 non-null  int64
#  17  dld_filename                     14889 non-null  int64
#  18  dld_getArg                       14889 non-null  int64
#  19  urlLen                           14889 non-null  int64
#  20  domainlength                     14889 non-null  int64
#  21  pathLength                       14889 non-null  int64
#  22  subDirLen                        14889 non-null  int64
#  23  fileNameLen                      14889 non-null  int64
#  24  this.fileExtLen                  14889 non-null  int64
#  25  ArgLen                           14889 non-null  int64
#  26  pathurlRatio                     14889 non-null  float64
#  27  ArgUrlRatio                      14889 non-null  float64
#  28  argDomanRatio                    14889 non-null  float64
#  29  domainUrlRatio                   14889 non-null  float64
#  30  pathDomainRatio                  14889 non-null  float64
#  31  argPathRatio                     14889 non-null  float64
#  32  executable                       14889 non-null  int64
#  33  isPortEighty                     14889 non-null  int64
#  34  NumberofDotsinURL                14889 non-null  int64
#  35  ISIpAddressInDomainName          14889 non-null  int64
#  36  CharacterContinuityRate          14889 non-null  float64
#  37  LongestVariableValue             14889 non-null  int64
#  38  URL_DigitCount                   14889 non-null  int64
#  39  host_DigitCount                  14889 non-null  int64
#  40  Directory_DigitCount             14889 non-null  int64
#  41  File_name_DigitCount             14889 non-null  int64
#  42  Extension_DigitCount             14889 non-null  int64
#  43  Query_DigitCount                 14889 non-null  int64
#  44  URL_Letter_Count                 14889 non-null  int64
#  45  host_letter_count                14889 non-null  int64
#  46  Directory_LetterCount            14889 non-null  int64
#  47  Filename_LetterCount             14889 non-null  int64
#  48  Extension_LetterCount            14889 non-null  int64
#  49  Query_LetterCount                14889 non-null  int64
#  50  LongestPathTokenLength           14889 non-null  int64
#  51  Domain_LongestWordLength         14889 non-null  int64
#  52  Path_LongestWordLength           14889 non-null  int64
#  53  sub-Directory_LongestWordLength  14889 non-null  int64
#  54  Arguments_LongestWordLength      14889 non-null  int64
#  55  URL_sensitiveWord                14889 non-null  int64
#  56  URLQueries_variable              14889 non-null  int64
#  57  spcharUrl                        14889 non-null  int64
#  58  delimeter_Domain                 14889 non-null  int64
#  59  delimeter_path                   14889 non-null  int64
#  60  delimeter_Count                  14889 non-null  int64
#  61  NumberRate_URL                   14889 non-null  float64
#  62  NumberRate_Domain                14889 non-null  float64
#  63  NumberRate_DirectoryName         14889 non-null  float64
#  64  NumberRate_FileName              14889 non-null  float64
#  65  NumberRate_AfterPath             14889 non-null  float64
#  66  SymbolCount_URL                  14889 non-null  int64
#  67  SymbolCount_Domain               14889 non-null  int64
#  68  SymbolCount_Directoryname        14889 non-null  int64
#  69  SymbolCount_FileName             14889 non-null  int64
#  70  SymbolCount_Extension            14889 non-null  int64
#  71  SymbolCount_Afterpath            14889 non-null  int64
#  72  Entropy_URL                      14889 non-null  float64
#  73  Entropy_Domain                   14889 non-null  float64
#  74  Entropy_Filename                 14889 non-null  float64
#  75  Entropy_Extension                14889 non-null  float64
#  76  Entropy_Afterpath                14889 non-null  float64
#  77  URL_Type_obf_Type                14889 non-null  object
# dtypes: float64(19), int64(58), object(1)
# memory usage: 8.9+ MB

# %%
# In Defacement Dataset nearly 39% of values are NULL values in the Entropy_DirectoryName
 # and 32% of values are NULL values in the NumberRate_Extension column

defacement1=defacement.drop(["NumberRate_Extension", "Entropy_DirectoryName"], axis=1)
defacement1=defacement1.dropna()
defacement1=shuffle(defacement1) 
defacement1=defacement1.reset_index(drop=True)
defacement1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15477 entries, 0 to 15476
# Data columns (total 78 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Querylength                      15477 non-null  int64
#  1   domain_token_count               15477 non-null  int64
#  2   path_token_count                 15477 non-null  int64
#  3   avgdomaintokenlen                15477 non-null  float64
#  4   longdomaintokenlen               15477 non-null  int64
#  5   avgpathtokenlen                  15477 non-null  float64
#  6   tld                              15477 non-null  int64
#  7   charcompvowels                   15477 non-null  int64
#  8   charcompace                      15477 non-null  int64
#  9   ldl_url                          15477 non-null  int64
#  10  ldl_domain                       15477 non-null  int64
#  11  ldl_path                         15477 non-null  int64
#  12  ldl_filename                     15477 non-null  int64
#  13  ldl_getArg                       15477 non-null  int64
#  14  dld_url                          15477 non-null  int64
#  15  dld_domain                       15477 non-null  int64
#  16  dld_path                         15477 non-null  int64
#  17  dld_filename                     15477 non-null  int64
#  18  dld_getArg                       15477 non-null  int64
#  19  urlLen                           15477 non-null  int64
#  20  domainlength                     15477 non-null  int64
#  21  pathLength                       15477 non-null  int64
#  22  subDirLen                        15477 non-null  int64
#  23  fileNameLen                      15477 non-null  int64
#  24  this.fileExtLen                  15477 non-null  int64
#  25  ArgLen                           15477 non-null  int64
#  26  pathurlRatio                     15477 non-null  float64
#  27  ArgUrlRatio                      15477 non-null  float64
#  28  argDomanRatio                    15477 non-null  float64
#  29  domainUrlRatio                   15477 non-null  float64
#  30  pathDomainRatio                  15477 non-null  float64
#  31  argPathRatio                     15477 non-null  float64
#  32  executable                       15477 non-null  int64
#  33  isPortEighty                     15477 non-null  int64
#  34  NumberofDotsinURL                15477 non-null  int64
#  35  ISIpAddressInDomainName          15477 non-null  int64
#  36  CharacterContinuityRate          15477 non-null  float64
#  37  LongestVariableValue             15477 non-null  int64
#  38  URL_DigitCount                   15477 non-null  int64
#  39  host_DigitCount                  15477 non-null  int64
#  40  Directory_DigitCount             15477 non-null  int64
#  41  File_name_DigitCount             15477 non-null  int64
#  42  Extension_DigitCount             15477 non-null  int64
#  43  Query_DigitCount                 15477 non-null  int64
#  44  URL_Letter_Count                 15477 non-null  int64
#  45  host_letter_count                15477 non-null  int64
#  46  Directory_LetterCount            15477 non-null  int64
#  47  Filename_LetterCount             15477 non-null  int64
#  48  Extension_LetterCount            15477 non-null  int64
#  49  Query_LetterCount                15477 non-null  int64
#  50  LongestPathTokenLength           15477 non-null  int64
#  51  Domain_LongestWordLength         15477 non-null  int64
#  52  Path_LongestWordLength           15477 non-null  int64
#  53  sub-Directory_LongestWordLength  15477 non-null  int64
#  54  Arguments_LongestWordLength      15477 non-null  int64
#  55  URL_sensitiveWord                15477 non-null  int64
#  56  URLQueries_variable              15477 non-null  int64
#  57  spcharUrl                        15477 non-null  int64
#  58  delimeter_Domain                 15477 non-null  int64
#  59  delimeter_path                   15477 non-null  int64
#  60  delimeter_Count                  15477 non-null  int64
#  61  NumberRate_URL                   15477 non-null  float64
#  62  NumberRate_Domain                15477 non-null  float64
#  63  NumberRate_DirectoryName         15477 non-null  float64
#  64  NumberRate_FileName              15477 non-null  float64
#  65  NumberRate_AfterPath             15477 non-null  float64
#  66  SymbolCount_URL                  15477 non-null  int64
#  67  SymbolCount_Domain               15477 non-null  int64
#  68  SymbolCount_Directoryname        15477 non-null  int64
#  69  SymbolCount_FileName             15477 non-null  int64
#  70  SymbolCount_Extension            15477 non-null  int64
#  71  SymbolCount_Afterpath            15477 non-null  int64
#  72  Entropy_URL                      15477 non-null  float64
#  73  Entropy_Domain                   15477 non-null  float64
#  74  Entropy_Filename                 15477 non-null  float64
#  75  Entropy_Extension                15477 non-null  float64
#  76  Entropy_Afterpath                15477 non-null  float64
#  77  URL_Type_obf_Type                15477 non-null  object
# dtypes: float64(19), int64(58), object(1)
# memory usage: 9.2+ MB

# %% [markdown]
# ### Merging all the four Data sets ###

# %%
# The final Dataset consists of 58972 rows, 77 features and 1 output feature
 # Appending all the DataFrames along rows

all_files=np.concatenate((malware1, spam1, phishing1, defacement1), axis=0)
all_files=pd.DataFrame(all_files, columns=malware1.columns)

all_files.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58972 entries, 0 to 58971
# Data columns (total 78 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Querylength                      58972 non-null  object
#  1   domain_token_count               58972 non-null  object
#  2   path_token_count                 58972 non-null  object
#  3   avgdomaintokenlen                58972 non-null  object
#  4   longdomaintokenlen               58972 non-null  object
#  5   avgpathtokenlen                  58972 non-null  object
#  6   tld                              58972 non-null  object
#  7   charcompvowels                   58972 non-null  object
#  8   charcompace                      58972 non-null  object
#  9   ldl_url                          58972 non-null  object
#  10  ldl_domain                       58972 non-null  object
#  11  ldl_path                         58972 non-null  object
#  12  ldl_filename                     58972 non-null  object
#  13  ldl_getArg                       58972 non-null  object
#  14  dld_url                          58972 non-null  object
#  15  dld_domain                       58972 non-null  object
#  16  dld_path                         58972 non-null  object
#  17  dld_filename                     58972 non-null  object
#  18  dld_getArg                       58972 non-null  object
#  19  urlLen                           58972 non-null  object
#  20  domainlength                     58972 non-null  object
#  21  pathLength                       58972 non-null  object
#  22  subDirLen                        58972 non-null  object
#  23  fileNameLen                      58972 non-null  object
#  24  this.fileExtLen                  58972 non-null  object
#  25  ArgLen                           58972 non-null  object
#  26  pathurlRatio                     58972 non-null  object
#  27  ArgUrlRatio                      58972 non-null  object
#  28  argDomanRatio                    58972 non-null  object
#  29  domainUrlRatio                   58972 non-null  object
#  30  pathDomainRatio                  58972 non-null  object
#  31  argPathRatio                     58972 non-null  object
#  32  executable                       58972 non-null  object
#  33  isPortEighty                     58972 non-null  object
#  34  NumberofDotsinURL                58972 non-null  object
#  35  ISIpAddressInDomainName          58972 non-null  object
#  36  CharacterContinuityRate          58972 non-null  object
#  37  LongestVariableValue             58972 non-null  object
#  38  URL_DigitCount                   58972 non-null  object
#  39  host_DigitCount                  58972 non-null  object
#  40  Directory_DigitCount             58972 non-null  object
#  41  File_name_DigitCount             58972 non-null  object
#  42  Extension_DigitCount             58972 non-null  object
#  43  Query_DigitCount                 58972 non-null  object
#  44  URL_Letter_Count                 58972 non-null  object
#  45  host_letter_count                58972 non-null  object
#  46  Directory_LetterCount            58972 non-null  object
#  47  Filename_LetterCount             58972 non-null  object
#  48  Extension_LetterCount            58972 non-null  object
#  49  Query_LetterCount                58972 non-null  object
#  50  LongestPathTokenLength           58972 non-null  object
#  51  Domain_LongestWordLength         58972 non-null  object
#  52  Path_LongestWordLength           58972 non-null  object
#  53  sub-Directory_LongestWordLength  58972 non-null  object
#  54  Arguments_LongestWordLength      58972 non-null  object
#  55  URL_sensitiveWord                58972 non-null  object
#  56  URLQueries_variable              58972 non-null  object
#  57  spcharUrl                        58972 non-null  object
#  58  delimeter_Domain                 58972 non-null  object
#  59  delimeter_path                   58972 non-null  object
#  60  delimeter_Count                  58972 non-null  object
#  61  NumberRate_URL                   58972 non-null  object
#  62  NumberRate_Domain                58972 non-null  object
#  63  NumberRate_DirectoryName         58972 non-null  object
#  64  NumberRate_FileName              58972 non-null  object
#  65  NumberRate_AfterPath             58972 non-null  object
#  66  SymbolCount_URL                  58972 non-null  object
#  67  SymbolCount_Domain               58972 non-null  object
#  68  SymbolCount_Directoryname        58972 non-null  object
#  69  SymbolCount_FileName             58972 non-null  object
#  70  SymbolCount_Extension            58972 non-null  object
#  71  SymbolCount_Afterpath            58972 non-null  object
#  72  Entropy_URL                      58972 non-null  object
#  73  Entropy_Domain                   58972 non-null  object
#  74  Entropy_Filename                 58972 non-null  object
#  75  Entropy_Extension                58972 non-null  object
#  76  Entropy_Afterpath                58972 non-null  object
#  77  URL_Type_obf_Type                58972 non-null  object
# dtypes: object(78)
# memory usage: 35.1+ MB

# %%
# Functions:-

# Function for Data Scaling
def dataset_scaling(dataset):
        
  # Scaling dataset
  scaler = MinMaxScaler(feature_range=(0, 1)) # Scaling object for features 
  
  df_X = dataset.loc[:, dataset.columns!="URL_Type_obf_Type"]
  df_Y = dataset[["URL_Type_obf_Type"]]
  
  df_X = scaler.fit_transform(df_X)
  dataset1=np.concatenate((df_X, df_Y), axis=1)
  
  return dataset1, scaler    

# Function for appending the features with high correlation
def columns_highcorr(corr, columns):
    index_highcorr=[]
    for i in range(0, corr.shape[0]):
        for j in range(i, corr.shape[1]):
            if(0.8<=corr.iloc[i][j]<1):
                print(columns[i],"and",columns[j],"with Correlation",round(corr.iloc[i][j],2))
                if(i not in index_highcorr):
                    index_highcorr.append(i);
                 
    return index_highcorr

# %%
# From the Previous Analysis it is clear that there are 45 features with no impact on the output variable
 # So, dropping all the 45 columns from the final Dataset
 
names_columns_worst=['Querylength', 'path_token_count', 'avgdomaintokenlen', 'longdomaintokenlen', 
                     'avgpathtokenlen', 'charcompvowels', 'charcompace', 'ldl_url', 'ldl_path', 
                     'ldl_filename', 'ldl_getArg', 'dld_url', 'dld_domain', 'dld_path', 
                     'dld_filename', 'urlLen', 'domainlength', 'pathLength', 'subDirLen', 
                     'this.fileExtLen', 'ArgLen', 'pathurlRatio', 'ArgUrlRatio', 'argDomanRatio', 
                     'argPathRatio', 'executable', 'isPortEighty', 'ISIpAddressInDomainName', 
                     'LongestVariableValue', 'URL_DigitCount', 'host_DigitCount', 'Directory_DigitCount', 
                     'Extension_DigitCount', 'Query_LetterCount', 'Path_LongestWordLength', 'URL_sensitiveWord', 
                     'URLQueries_variable', 'spcharUrl', 'delimeter_Count', 'NumberRate_Domain', 'NumberRate_DirectoryName', 
                     'NumberRate_AfterPath', 'SymbolCount_URL', 'SymbolCount_FileName', 'SymbolCount_Extension']

# %%
all_files1=all_files.drop(columns=names_columns_worst) # Dropping all the above features
 
# Saving the above Dataframe as a csv file and loading it for further evaluation

all_files1.to_csv("/Users/ruthvikrajam.v/Desktop/All Files.csv",index=False)
all_files1=pd.read_csv("/Users/ruthvikrajam.v/Desktop/All Files.csv")

# %%
# Checking further if there are any features with high Correlation 

corr=all_files1.corr()
index_allfiles_highcorr=columns_highcorr(corr, corr.columns)
all_files2=all_files1.drop(columns=corr.columns[index_allfiles_highcorr])
# 58,972 rows and 27 columns
# Out:
# domain_token_count and SymbolCount_Domain with Correlation 1.0
# tld and SymbolCount_Domain with Correlation 1.0
# pathDomainRatio and URL_Letter_Count with Correlation 0.91
# pathDomainRatio and Extension_LetterCount with Correlation 0.89
# pathDomainRatio and LongestPathTokenLength with Correlation 0.92
# Query_DigitCount and URL_Letter_Count with Correlation 0.86
# Query_DigitCount and Extension_LetterCount with Correlation 0.87
# Query_DigitCount and LongestPathTokenLength with Correlation 0.89
# URL_Letter_Count and Extension_LetterCount with Correlation 0.95
# URL_Letter_Count and LongestPathTokenLength with Correlation 0.97
# Extension_LetterCount and LongestPathTokenLength with Correlation 0.97

# %%
# Assigning labels to the classes

all_files3=all_files2.copy() # Modifications done in all_files3 wont be reflected in all_files2
        
all_files3["URL_Type_obf_Type"]=all_files3["URL_Type_obf_Type"].map({"Defacement":0, "benign":1, "malware":2, "phishing":3, "spam":4 })

# %%
# Scaling the Dataset

all_files4, scaler=dataset_scaling(all_files3)
all_files4=pd.DataFrame(all_files4, columns=all_files3.columns)

# %%
# Principal Component Analysis -> Dimensionality Reduction

# Separating the input and output features
X=all_files4.loc[:, all_files4.columns!="URL_Type_obf_Type"]
y=all_files4["URL_Type_obf_Type"]
  
# Let's say, components = 10
pca = PCA(n_components = 10)
pca.fit(X)
X_pca = pca.transform(X)

# %%
# Splitting the samples
train_x, test_x, train_y, test_y=train_test_split(X_pca, y, random_state=0, test_size=0.25)

# %%
# Machine Learning Models
start = time.time()
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(train_x, train_y)
predicted_test=knn.predict(test_x)
end = time.time()
print((end-start)) # Prints Time taken by the Model to train and execute the samples in seconds

# Predicting the Output
predicted_train=knn.predict(train_x)
# Out:
# 0.9810070991516113

# %%
# Performance Metrics
print(accuracy_score(test_y, predicted_test) * 100) # 96% for testing
print(accuracy_score(train_y, predicted_train) * 100) # 97% for training

# Time taken by PCA to execute -> 0.933 seconds
# Out:
# 95.85566031336906
# 97.11275407538041

# %% [markdown]
# ## If we consider all the columns in the Dataset i.e 77 features:-

# %%
all_files_features=all_files.copy()
all_files_features["URL_Type_obf_Type"]=all_files_features["URL_Type_obf_Type"].map({"Defacement":0, "benign":1, "malware":2, "phishing":3, "spam":4 })

# %%
all_files_features1, scaler=dataset_scaling(all_files_features)
all_files_features1=pd.DataFrame(all_files_features1, columns=all_files_features.columns)

# %%
# Splitting the samples
train_x, test_x, train_y, test_y=train_test_split(all_files_features1.loc[:, all_files_features1.columns!="URL_Type_obf_Type"], all_files_features1["URL_Type_obf_Type"], random_state=0, test_size=0.25)

# %%
# Machine Learning Models
start = time.time()
knn=KNeighborsClassifier(n_neighbors=7)
knn.fit(train_x, train_y)
predicted_test=knn.predict(test_x)
end = time.time()
print((end-start)) # Prints Time taken by the Model to train and execute the samples in seconds

# Predicting the Output
predicted_train=knn.predict(train_x)
# Out:
# 21.16399383544922

# %%
# Performance Metrics
print(accuracy_score(test_y, predicted_test) * 100)
print(accuracy_score(train_y, predicted_train) * 100)

# Takes 22.5 seconds, Testing accuracy score -> 95.9% and Training accuracy score -> 97%, when we try to use all the features
# Out:
# 95.81496303330394
# 96.92961631508739

# %% [markdown]
# ### <---------------------- THE END -----------------------> ###
